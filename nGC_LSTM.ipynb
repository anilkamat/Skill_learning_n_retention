# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, GaussianNoise, Flatten, Activation, Dropout, RepeatVector, Permute, Lambda, concatenate, dot, multiply
from tensorflow.keras.models import Model
from keras.layers import TimeDistributed
from keras.models import load_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import pandas as pd
import os
import time
def normalize(data):
  min = np.min(data, axis = 0)
  max = np.max(data, axis = 0)
  #print('min, max',min, max)
  data = (data-min)/(max-min)
  return data

# Generate sample data
def generate_data(n_points, n_features, window_size, data = None):
    if data is None:
      data = np.random.randn(n_points, n_features)
    data = normalize(data)
    #data = np.random.normal(loc= 0.0, scale= 1.0 ,size = (n_points, n_features))
    X = []
    Y = []
    #print(data)
    for i in range(0, n_points-2*window_size+1):
      X.append(data[i:i+window_size,:])
      Y.append(data[i+window_size:i+2*window_size,:])
    return X, Y

# %%
#connections =['LPFC --> RPFC ','LPFC --> LPMC ','LPFC --> RPMC ','LPFC --> LPAR ','LPFC --> RPAR ','LPFC --> LSMA ','RPFC --> LPFC ','RPFC --> LPMC ','RPFC --> RPMC ','RPFC --> LPAR ','RPFC --> RPAR ','RPFC --> LSMA ','LPMC --> LPFC ','LPMC --> RPFC ','LPMC --> RPMC ','LPMC --> LPAR ','LPMC --> RPAR ','LPMC --> LSMA ','RPMC --> LPFC ','RPMC --> RPFC ','RPMC --> LPMC ','RPMC --> LPAR ','RPMC --> RPAR ','RPMC --> LSMA ','LPAR --> LPFC ','LPAR --> RPFC ','LPAR --> LPMC ','LPAR --> RPMC ','LPAR --> RPAR ','LPAR --> LSMA ','RPAR --> LPFC ','RPAR --> RPFC ','RPAR --> LPMC ','RPAR --> RPMC ','RPAR --> LPAR ','RPAR --> LSMA ','LSMA --> LPFC ','LSMA --> RPFC ','LSMA --> LPMC ','LSMA --> RPMC ','LSMA --> LPAR ','LSMA --> RPAR ']
connections1 = ['LPFC-->RPFC','LPFC-->LPMC','LPFC-->RPMC','LPFC-->SMA',\
    'RPFC-->LPFC','RPFC-->LPMC','RPFC-->RPMC','RPFC-->SMA',\
    'LPMC-->LPFC','LPMC-->RPFC','LPMC-->RPMC','LPMC-->SMA',\
    'RPMC-->LPFC','RPMC-->RPFC','RPMC-->LPMC','RPMC-->SMA',\
    'SMA-->LPFC','SMA-->RPFC','SMA-->LPMC','SMA-->RPMC','Class']

connections2 = ['LPFC-->LPFC','LPFC-->RPFC','LPFC-->LPMC','LPFC-->RPMC','LPFC-->SMA','RPFC-->LPFC','RPFC-->RPFC','RPFC-->LPMC','RPFC-->RPMC','RPFC-->SMA','LPMC-->LPFC','LPMC-->RPFC','LPMC-->LPMC','LPMC-->RPMC','LPMC-->SMA','RPMC-->LPFC','RPMC-->RPFC','RPMC-->LPMC','RPMC-->RPMC','RPMC-->SMA','SMA-->LPFC','SMA-->RPFC','SMA-->LPMC','SMA-->RPMC','SMA-->SMA','Class']

# %%
# "" This function groups the channels in each brain region andsend the regional signals ""
Lpfc_channels = {'AFp1','AFF5h','F7','AFF1h','FFC5h'}
Rpfc_channels = {'AFp2','AFF6H','F8','AFF2h','FFC6h'}
sma_channels = {'FFC3h', 'FCC3h','FFC4h', 'FCC4h'}
lpmc_channels = {'FCC5h','CCP5h','CCP3h','P3','P5','PO7','P7','PO3'}
rpmc_channels = {'FCC6h','CCP6h','CCP4h','P4','P6','PO8','P8','PO4'}
Lpfc_ch_num =[0,1,2,3,4]
Rpfc_ch_num =[16,17,18,19,20]
SMA_ch_num  =[5,7,21,23]
Lpmc_ch_num =[6,8,9,10,11,12,13,14]
Rpmc_ch_num =[22,24,25,26,27,28,29,30]

# channels not in the ROI: 15,31, the removal of these channels from the features set will effect the channel number/order
chan_removed = [15,31]
# Modified channel numbers
Lpfc_ch_num =[0,1,2,3,4]    # no change in order
Rpfc_ch_num =[15,16,17,18,19]   # Modified
SMA_ch_num  =[5,7,20,22]  # Modified
Lpmc_ch_num =[6,8,9,10,11,12,13,14]  # no change in order
Rpmc_ch_num =[21,23,24,25,26,27,28,29]  #Modified

Reg_ch_num =[[0,1,2,3,4],
[15,16,17,18,19],
[5,7,20,22],
[6,8,9,10,11,12,13,14],
[21,23,24,25,26,27,28,29]]

# list of channel in the order it appears in the dataset
chan_list =['AFp1','AFF5h','F7','AFF1h','FFC5h','FFC3h','FCC5h','FCC3h',\
            'CCP5h','CCP3h','P3','P5','PO7','P7','PO3','FT7','AFp2',\
            'AFF6H','F8','AFF2h','FFC6h','FFC4h','FCC6h','FCC4h','CCP6h',\
            'CCP4h','P4','P6','PO8','P8','PO4','FT8']
# for i, item in enumerate(chan_list):
#   print(i,item)

# %%
# Parameters
win_size = [3,5] #[3,5,7,9] # input = ouput = window_size
eps = 2000 # epochs
bs = 16 # Batch size
latent_dim =  64 # 128 #(optimal)
n_Bregions = 5
st = time.time()
phase = 'ST10'
Days = ['D10','D11']

for Day in Days:
  # /content/EEG_signal_copy
  # directories for alpha band signals
  dir = # directory of the EEG activation/signal files
  csvfilename = # directory to stoare the computed connectivities of the group
  file_path = # directory to save best window based on R-square value
  
  Causal_allSub = []
  sub_num = 1 # counter for subjects
  r_squares = []  # list of r-squares (max) of full models after tuning
  best_windows = []  # list of best windows full models after model tuning
  for sub in sorted(os.listdir(dir)):
    print(f'{sub_num} filename: {sub}')
    sub_num += 1
    data = pd.read_csv(os.path.join(dir,sub), header=None, index_col = None)
    data.drop(data.columns[chan_removed], axis=0, inplace=True) # remove the out of ROI channels
    data = data.to_numpy().T
    n_features = data.shape[1]
    n_points = data.shape[0]
    R2 = []
    r2_sum_max = 0  # place holder
    best_winsize = 0 # just a place holder, size of 0 is not used in the final model. 
    for window_size in win_size:
      n_train = int((n_points-2*window_size)*0.8)  #80% training samples
      X, Y = generate_data(n_points, n_features, window_size, data)
      X_train, y_train = np.stack(X[:n_train]), np.stack(Y[:n_train])
      X_test, y_test = np.stack(X[n_train:]), np.stack(Y[n_train:])
      dropout_rate = 0.4 
      inputs = Input(shape=(None, n_features))
      # First LSTM layer in the encoder with return_sequences=True
      # encoded = LSTM(latent_dim, activation='selu', return_sequences=True, go_backwards=True)(inputs)
      # encoded = Dropout(dropout_rate)(encoded)  # Adding dropout after the first LSTM layer
      # Second LSTM layer in the encoder
      encoded, state_h, state_c = LSTM(latent_dim, activation='selu', return_sequences=True, return_state=True)(inputs)
      encoder_states = [state_h, state_c]
      attention = Dense(1, activation='tanh')(encoded)
      attention = Flatten()(attention)
      attention = Activation('softmax', name='attention')(attention)
      attention = RepeatVector(latent_dim)(attention)
      attention = Permute([2, 1])(attention)
      encoded = multiply([encoded, attention])
      # context = Lambda(lambda xin: tf.keras.backend.sum(xin, axis=1))(encoded)
      context = Lambda(lambda xin: tf.keras.backend.sum(xin, axis=1))(encoded)
      # Decoder
      decoder_input = Lambda(lambda x: tf.keras.backend.repeat(x[0], tf.shape(x[1])[1]))([context, inputs])
      # First LSTM layer in the decoder with return_sequences=True
      decoded = LSTM(latent_dim, activation='selu', return_state=False, return_sequences=True)(decoder_input, initial_state=encoder_states)
      decoded = Dropout(dropout_rate)(decoded)  # Adding dropout after the first LSTM layer
      # Experiment with this attention module
      attention = dot([decoded, encoded], axes=[2, 2])
      attention = Activation('softmax')(attention)
      attention = dot([attention, encoded], axes=[2,1])
      decoded = concatenate([attention, decoded])
      decoded = TimeDistributed(Dense(n_features), name='autoencoder')(decoded)
      # Define models
      encoder = Model(inputs, context)
      autoencoder = Model(inputs, decoded)
      autoencoder.compile(optimizer="adam", loss="mse")

      # Train model
      es = EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)
      history = autoencoder.fit(X_train, y_train, epochs=eps, batch_size=bs, verbose=0, validation_split=0.1, callbacks = [es]) #hide training progress
      y_pred = autoencoder.predict(X_test)
      yy_pred = y_pred.reshape(-1,n_features)
      yy_test = y_test.reshape(-1,n_features)
      mse = []
      mae = []
      rmse = []
      r2 = []
      for i in range(n_features):
        mse.append(mean_squared_error(yy_test[:,i], yy_pred[:,i]))  #self causal when i ==0
        mae.append(mean_absolute_error(yy_test[:,i], yy_pred[:,i]))
        rmse.append(np.sqrt(mean_squared_error(yy_test[:,i], yy_pred[:,i])))
        r2.append(r2_score(yy_test[:,i], yy_pred[:,i]))
      R2.append(r2)
      r2_sum = np.mean(r2)
      if r2_sum > r2_sum_max:   # if r2_sum is smaller than zero, the model is not acceptable.
        r2_sum_max = r2_sum
        best_winsize = window_size
    r_squares.append(r2_sum_max)
    best_windows.append(best_winsize)

    df2 = pd.DataFrame({'R_squares': r_squares, 'best-windows': best_windows})
    df2.to_csv(file_path, index = False)

    np.mean(R2, axis= 1)
    R2max_ind = np.argmax(np.mean(R2, axis= 1))
    best_winsize = win_size[R2max_ind]
    ## START of train/test of final model ##
    if len(win_size) >1 and best_winsize != win_size[-1]:
      n_train = int((n_points-2*best_winsize)*0.8)  
      # Generate data
      X, Y = generate_data(n_points, n_features, best_winsize, data)
      X_train, y_train = np.stack(X[:n_train]), np.stack(Y[:n_train])
      X_test, y_test = np.stack(X[n_train:]), np.stack(Y[n_train:])
      dropout_rate = 0.4  # Example dropout rate
      inputs = Input(shape=(None, n_features))
      # First LSTM layer in the encoder with return_sequences=True
      # encoded = LSTM(latent_dim, activation='selu', return_sequences=True, go_backwards=True)(inputs)
      # encoded = Dropout(dropout_rate)(encoded)  # Adding dropout after the first LSTM layer
      # Second LSTM layer in the encoder
      encoded, state_h, state_c = LSTM(latent_dim, activation='selu', return_sequences=True, return_state=True)(inputs)
      encoder_states = [state_h, state_c]
      # Compute importance for each step
      attention = Dense(1, activation='tanh')(encoded)
      attention = Flatten()(attention)
      attention = Activation('softmax', name='attention')(attention)
      attention = RepeatVector(latent_dim)(attention)
      attention = Permute([2, 1])(attention)
      encoded = multiply([encoded, attention])
      # context = Lambda(lambda xin: tf.keras.backend.sum(xin, axis=1))(encoded)
      context = Lambda(lambda xin: tf.keras.backend.sum(xin, axis=1))(encoded)
      # Decoder
      decoder_input = Lambda(lambda x: tf.keras.backend.repeat(x[0], tf.shape(x[1])[1]))([context, inputs])
      # First LSTM layer in the decoder with return_sequences=True
      decoded = LSTM(latent_dim, activation='selu', return_state=False, return_sequences=True)(decoder_input, initial_state=encoder_states)
      decoded = Dropout(dropout_rate)(decoded)  # Adding dropout after the first LSTM layer
      # Second LSTM layer in the decoder
      # decoded = LSTM(latent_dim, activation='selu', return_sequences=True)(decoded)
      # Experiment with this attention module
      attention = dot([decoded, encoded], axes=[2, 2])
      attention = Activation('softmax')(attention)
      attention = dot([attention, encoded], axes=[2,1])
      decoded = concatenate([attention, decoded])
      decoded = TimeDistributed(Dense(n_features), name='autoencoder')(decoded)
      encoder = Model(inputs, context)
      autoencoder = Model(inputs, decoded)
      # Compile model
      autoencoder.compile(optimizer="adam", loss="mse")
      es = EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True)
      history = autoencoder.fit(X_train, y_train, epochs=eps, batch_size=bs, verbose=0, validation_split=0.1, callbacks = [es]) #hide training progress

    ## compute the causality
    def modify_feature(X, feature_index):
        X_modified = X.copy()
        X_modified[:, :, Reg_ch_num[feature_index]] = 0 
        return X_modified

    def calculate_metrics(y_test, y_pred, n_features, n_Bregions):
        mse, mae, rmse, r2, variance = [], [], [], [], []
        yy_test = y_test.reshape(-1, n_features)
        yy_pred = y_pred.reshape(-1, n_features)
        for i in range(n_Bregions):
            # mse.append(mean_squared_error(yy_test[:, i], yy_pred[:, i]))
            # mae.append(mean_absolute_error(yy_test[:, i], yy_pred[:, i]))
            # rmse.append(np.sqrt(mse[-1]))
            r2.append(r2_score(yy_test[:, Reg_ch_num[i]], yy_pred[:, Reg_ch_num[i]]))
            variance.append(np.var(yy_test[:, Reg_ch_num[i]] - yy_pred[:, Reg_ch_num[i]]))
        return variance

    original_variance = []  # Store original variances here
    y_pred_original = autoencoder.predict(X_test)
    original_variance = calculate_metrics(y_test, y_pred_original, n_features, n_Bregions)

    # Loop over all features
    causality_mat = []
    for feature_index in range(n_Bregions):
        X_test_modified = modify_feature(X_test, feature_index)
        y_pred_modified = autoencoder.predict(X_test_modified)
        modified_variance = calculate_metrics(y_test, y_pred_modified, n_features, n_Bregions)
        causal_effect = np.log(np.array(modified_variance) / np.array(original_variance))
        causality_mat.append(causal_effect)
    expertise = 1 if sub[0:3]=='Exp' else -1
    causality_flat = np.append(np.array(causality_mat).flatten(), int(expertise))
    Causal_allSub.append(causality_flat)

  # write causality to csv files
  df =pd.DataFrame(np.vstack((connections2, np.array(Causal_allSub))))
  df.to_csv(csvfilename, header=None, index=None)
et = time.time()
print(f'Total time take: {(et-st)/60} min')
# Out:
# 1 filename: P01Tr_1_alphafreqBP.csv
# WARNING:tensorflow:From c:\Users\_Kamat_\Desktop\RPI\ResearchWork\Papers_\Effective_Connectivity\tfLSTM_ED\lib\site-packages\keras\src\backend\tensorflow\core.py:187: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2 filename: P01Tr_2_alphafreqBP.csv
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3 filename: P01Tr_3_alphafreqBP.csv
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4 filename: P01Tr_4_alphafreqBP.csv
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 5 filename: P01Tr_5_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6 filename: P02Tr_1_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7 filename: P02Tr_2_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8 filename: P02Tr_3_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9 filename: P02Tr_4_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10 filename: P02Tr_5_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11 filename: P03Tr_1_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12 filename: P03Tr_2_alphafreqBP.csv
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13 filename: P03Tr_3_alphafreqBP.csv
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14 filename: P03Tr_4_alphafreqBP.csv
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15 filename: P03Tr_5_alphafreqBP.csv
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16 filename: P04Tr_1_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17 filename: P04Tr_2_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18 filename: P04Tr_3_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19 filename: P05Tr_1_alphafreqBP.csv
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20 filename: P05Tr_2_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21 filename: P05Tr_3_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22 filename: P05Tr_4_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 23 filename: P05Tr_5_alphafreqBP.csv
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24 filename: P06Tr_1_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25 filename: P06Tr_2_alphafreqBP.csv
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26 filename: P06Tr_3_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 27 filename: P06Tr_4_alphafreqBP.csv
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 28 filename: P07Tr_1_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29 filename: P07Tr_2_alphafreqBP.csv
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 30 filename: P07Tr_3_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 31 filename: P07Tr_4_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32 filename: P07Tr_5_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 33 filename: P08Tr_1_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 34 filename: P08Tr_2_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 35 filename: P08Tr_3_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36 filename: P08Tr_4_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 37 filename: P08Tr_5_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 38 filename: P11Tr_2_alphafreqBP.csv
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 39 filename: P11Tr_3_alphafreqBP.csv
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 40 filename: P11Tr_4_alphafreqBP.csv
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 41 filename: P11Tr_5_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 42 filename: P12Tr_1_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 43 filename: P12Tr_2_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 44 filename: P12Tr_3_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 45 filename: P12Tr_4_alphafreqBP.csv
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46 filename: P12Tr_5_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 47 filename: P13Tr_1_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 48 filename: P13Tr_2_alphafreqBP.csv
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 49 filename: P13Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 50 filename: P13Tr_4_alphafreqBP.csv
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 51 filename: P13Tr_5_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 52 filename: P14Tr_1_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 53 filename: P14Tr_2_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 54 filename: P14Tr_3_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 55 filename: P14Tr_4_alphafreqBP.csv
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 56 filename: P14Tr_5_alphafreqBP.csv
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 57 filename: P15Tr_1_alphafreqBP.csv
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 58 filename: P15Tr_2_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 59 filename: P15Tr_3_alphafreqBP.csv
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 60 filename: P15Tr_4_alphafreqBP.csv
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 61 filename: P15Tr_5_alphafreqBP.csv
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 62 filename: P16Tr_1_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63 filename: P16Tr_2_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64 filename: P16Tr_3_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 65 filename: P16Tr_4_alphafreqBP.csv
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 66 filename: P16Tr_5_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 67 filename: P17Tr_1_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 68 filename: P17Tr_2_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 69 filename: P17Tr_3_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 70 filename: P17Tr_4_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 71 filename: P17Tr_5_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 72 filename: P18Tr_1_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 73 filename: P18Tr_2_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 74 filename: P18Tr_3_alphafreqBP.csv
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 75 filename: P18Tr_4_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 76 filename: P18Tr_5_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 77 filename: P19Tr_1_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 78 filename: P19Tr_2_alphafreqBP.csv
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 79 filename: P19Tr_3_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 80 filename: P19Tr_4_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 81 filename: P19Tr_5_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 82 filename: P21Tr_1_alphafreqBP.csv
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83 filename: P21Tr_2_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 84 filename: P21Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 85 filename: P21Tr_4_alphafreqBP.csv
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 86 filename: P21Tr_5_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 87 filename: P22Tr_1_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 88 filename: P22Tr_2_alphafreqBP.csv
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89 filename: P22Tr_3_alphafreqBP.csv
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 90 filename: P22Tr_4_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 91 filename: P22Tr_5_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 92 filename: P23Tr_1_alphafreqBP.csv
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 93 filename: P23Tr_2_alphafreqBP.csv
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 94 filename: P23Tr_3_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 95 filename: P23Tr_4_alphafreqBP.csv
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 96 filename: P23Tr_5_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 97 filename: P25Tr_1_alphafreqBP.csv
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 98 filename: P25Tr_2_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 99 filename: P25Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 100 filename: P25Tr_4_alphafreqBP.csv
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 101 filename: P25Tr_5_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102 filename: P26Tr_1_alphafreqBP.csv
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 103 filename: P26Tr_2_alphafreqBP.csv
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 104 filename: P26Tr_3_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 105 filename: P26Tr_4_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 106 filename: P26Tr_5_alphafreqBP.csv
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 107 filename: P28Tr_1_alphafreqBP.csv
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 108 filename: P28Tr_2_alphafreqBP.csv
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 109 filename: P28Tr_3_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 110 filename: P28Tr_4_alphafreqBP.csv
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111 filename: P28Tr_5_alphafreqBP.csv
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1 filename: P01Tr_2_alphafreqBP.csv
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2 filename: P01Tr_3_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3 filename: P01Tr_4_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4 filename: P01Tr_5_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5 filename: P01Tr_6_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6 filename: P01Tr_7_alphafreqBP.csv
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7 filename: P02Tr_1_alphafreqBP.csv
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8 filename: P02Tr_2_alphafreqBP.csv
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9 filename: P02Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10 filename: P02Tr_4_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11 filename: P02Tr_5_alphafreqBP.csv
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12 filename: P02Tr_6_alphafreqBP.csv
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13 filename: P02Tr_7_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14 filename: P03Tr_1_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15 filename: P03Tr_2_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16 filename: P03Tr_3_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17 filename: P03Tr_4_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18 filename: P03Tr_5_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19 filename: P03Tr_6_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20 filename: P03Tr_7_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 21 filename: P04Tr_1_alphafreqBP.csv
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22 filename: P04Tr_2_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23 filename: P04Tr_3_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24 filename: P04Tr_4_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25 filename: P04Tr_5_alphafreqBP.csv
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26 filename: P04Tr_6_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 27 filename: P04Tr_7_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 28 filename: P05Tr_1_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 29 filename: P05Tr_2_alphafreqBP.csv
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 30 filename: P05Tr_3_alphafreqBP.csv
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31 filename: P06Tr_1_alphafreqBP.csv
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32 filename: P06Tr_2_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 33 filename: P06Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 34 filename: P06Tr_4_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 35 filename: P06Tr_5_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 36 filename: P06Tr_6_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 37 filename: P06Tr_7_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 38 filename: P07Tr_1_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 39 filename: P07Tr_2_alphafreqBP.csv
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 40 filename: P07Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 41 filename: P07Tr_4_alphafreqBP.csv
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 42 filename: P07Tr_5_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 43 filename: P07Tr_6_alphafreqBP.csv
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 90 filename: P19Tr_2_alphafreqBP.csv
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 91 filename: P19Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 92 filename: P19Tr_4_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 93 filename: P19Tr_5_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 94 filename: P19Tr_6_alphafreqBP.csv
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 95 filename: P19Tr_7_alphafreqBP.csv
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 96 filename: P20Tr_1_alphafreqBP.csv
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 97 filename: P20Tr_2_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 98 filename: P20Tr_3_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 99 filename: P20Tr_4_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 100 filename: P20Tr_5_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 101 filename: P20Tr_6_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 102 filename: P20Tr_7_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 103 filename: P21Tr_1_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 104 filename: P21Tr_2_alphafreqBP.csv
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 105 filename: P21Tr_3_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 106 filename: P21Tr_4_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 107 filename: P21Tr_5_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 108 filename: P21Tr_6_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 109 filename: P21Tr_7_alphafreqBP.csv
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 110 filename: P23Tr_1_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 111 filename: P23Tr_2_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 112 filename: P23Tr_3_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 113 filename: P23Tr_4_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 114 filename: P23Tr_5_alphafreqBP.csv
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 115 filename: P23Tr_6_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 116 filename: P23Tr_7_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 117 filename: P25Tr_1_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 118 filename: P25Tr_2_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 119 filename: P25Tr_3_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 120 filename: P25Tr_4_alphafreqBP.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 121 filename: P25Tr_5_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 122 filename: P25Tr_6_alphafreqBP.csv
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 123 filename: P25Tr_7_alphafreqBP.csv
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 124 filename: P26Tr_1_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 125 filename: P26Tr_2_alphafreqBP.csv
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 126 filename: P26Tr_3_alphafreqBP.csv
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 127 filename: P26Tr_4_alphafreqBP.csv
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 128 filename: P26Tr_5_alphafreqBP.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 129 filename: P26Tr_6_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 130 filename: P26Tr_7_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 131 filename: P27Tr_1_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 132 filename: P27Tr_2_alphafreqBP.csv
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 133 filename: P27Tr_3_alphafreqBP.csv
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 134 filename: P27Tr_4_alphafreqBP.csv
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 135 filename: P27Tr_5_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 136 filename: P27Tr_7_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 137 filename: P28Tr_1_alphafreqBP.csv
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 138 filename: P28Tr_2_alphafreqBP.csv
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 139 filename: P28Tr_3_alphafreqBP.csv
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 140 filename: P28Tr_4_alphafreqBP.csv
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Total time take: 791.3061767578125 min
